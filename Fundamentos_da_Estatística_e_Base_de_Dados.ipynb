# %% [markdown]
# <a href="https://colab.research.google.com/github/Wallacekenchi/APIsNavegadores/blob/main/Fundamentos_da_Estat%C3%ADstica_e_Base_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fundamentos da Estatística e Base de Dados
#
#
# Nesta aula, vamos entender o que é estatística e criar a base que será usada nas próximas aulas.
#
# **Ideia central:** estatística serve para resumir e interpretar dados.

# %% [markdown]
# ## O que é estatística?
#
# Estatística é a área que nos ajuda a:
# - organizar dados
# - resumir dados
# - enxergar padrões
# - tomar decisões com mais critério
#
# Em análise de dados, ela ajuda a responder:
# - o que está acontecendo?
# - isso é comum ou estranho?
# - esse valor representa bem a base?

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)

# %%
# listas - []
supermercado = ["arroz", "feijao", "carne"]

# %%
supermercado.append("macarrão")

# %%
supermercado
# Out:
# ['arroz', 'feijao', 'carne', 'macarrão']

# %%
type(supermercado)
# Out:
# list

# %%
# Tuplas - ()
supermercado = ("Arroz", "feijao")

# %%
type(supermercado)
# Out:
# tuple

# %%
supermercado.append("macarrão")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10887/3724684589.py in <cell line: 0>()
# ----> 1 supermercado.append("macarrão")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Dicionarios -> Json -{}
supermercado = {
    "Carboidratos" : ['arroz', 'feijao', 'macarrão'],
    "Proteina" : ['arroz', 'feijao', 'macarrão'],
    "Doce" : ['arroz', 'feijao', 'macarrão']
}

pd.DataFrame(supermercado)
# Out:
#   Carboidratos  Proteina      Doce
# 0        arroz     arroz     arroz
# 1       feijao    feijao    feijao
# 2     macarrão  macarrão  macarrão

# %%
base = {
    "idade": np.clip(np.random.normal(32, 6, 120).round(), 20, 55),
    "salario": np.clip(np.random.normal(4500, 1200, 120), 1800, 12000),
    "horas_estudo": np.clip(np.random.normal(6, 2, 120), 1, 15),
    "area": np.random.choice(
        ["Comercial", "Marketing", "Financeiro", "Operações", "RH"],
        size=120,
        p=[0.30, 0.20, 0.20, 0.20, 0.10]
    )
}

# %% [markdown]
# ## Primeiro contato com a base
#
# Vamos olhar as primeiras linhas e o formato da base.

# %% [markdown]
# ## Perguntas para pensar
#
# 1. Quais colunas parecem numéricas?
# 2. Qual coluna parece categórica?
# 3. Que tipo de análise você imagina fazer nessa base?
